# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import pandas as pd

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Reading data with Python
#
# As we saw on previous courses we can read data simply using Python.
#
# When you want to work with a file, the first thing to do is to open it. This is done by invoking the `open()` built-in function.
#
# `open()` has a single required argument that is the path to the file and has a single return, the file object.
#
# The `with` statement automatically takes care of closing the file once it leaves the `with` block, even in cases of error.

# %%
filepath = 'Movimientos_cuenta_0184491.xls'

with open(filepath, 'r') as reader:
    print(reader)
# Out:
# <_io.TextIOWrapper name='Movimientos_cuenta_0184491.xls' mode='r' encoding='cp1252'>

# %% [markdown]
# Once the file is opened, we can read its content as follows:

# %%
filepath = 'Movimientos_cuenta_0184491.xls'

with open(filepath, 'r',encoding="iso-8859-1") as reader:
    for index, line in enumerate(reader.readlines()):
        # read just the first 10 lines
        if (index < 10):
            print(index, line)
# Out:
# 0 ÐÏà¡±á;þÿ	$þÿÿÿþÿÿÿ%ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÓÌAâ8ÿÿÿÿÿÿÿÿÿÿÿÿÀÀÀÿ3fÿÿÌÌÿÿffÿfÌÌÌÿÿÿÿÿÿÿÿÌÿÌÿÿÌÿÌÿÿÌÿO½ÌÿÿÌ3fÿ3ÌÌÌÿÌÿÿfff3f3f33333f33333á°Áâ\pweblogic                                                                                                     B°a=¯¼=h\:¾#8X@"·Ú1ÈÿArial1ÈÿArial1ÈÿArial1ÈÿArial1È¼Calibri1È¼Calibri1È	¼Calibri1ÈCalibri1È
#
# 1 Calibri"$"#,##0_);\("$"#,##0\)!"$"#,##0_);[Red]\("$"#,##0\)""$"#,##0.00_);\("$"#,##0.00\)'""$"#,##0.00_);[Red]\("$"#,##0.00\)7*2_("$"* #,##0_);_("$"* \(#,##0\);_("$"* "-"_);_(@_).))_(* #,##0_);_(* \(#,##0\);_(* "-"_);_(@_)?,:_("$"* #,##0.00_);_("$"* \(#,##0.00\);_("$"* "-"??_);_(@_)6+1_(* #,##0.00_);_(* \(#,##0.00\);_(* "-"??_);_(@_)¤
#
# 2 dd/MM/yyyyàõÿ À àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ àõÿ ôÀ à À à+õÿ øÀ à)õÿ øÀ à,õÿ øÀ à*õÿ øÀ à	õÿ øÀ à"8À à#8À à8­ à8­ à (À à¤#8À à#8À à	#8À ÿÿÿÿÿÿ`"«Movimientos_cuenta_0184491ü¦ø3VMovimientos de la cuenta ES25 2100 2809 1301 0018 4491 (CCC: 2100 2809 13 01 00184491)Importes expresados en eurosFechaFecha valor
#
# 3 Movimiento	Más datosImporteSaldoTo Revolut -3FFH-Az Eddine Derkaoui ChhibouHOTEL TRYP GRAN SFecha de operación: 08-03-2024TRANSFER INMEDIATAREINT.CAJERO
#
# 4 BIZUM ENVIADOTo Revolut -O5J1-UGT PAIS VALENG46949863002INGRESO CAJEROERROR SACAR DINEROGastos MensualesAz Eddine DerkaouiTRF.INTERNACIONALAZ EDDINE DERKAOUI CHHIBOUPEPEMOBILE S.LRecibo de teléfonoRevolut**2175*Fecha de operación: 25-09-2023CERRAJEROS B ANDFecha de operación: 16-07-2023BIZUM RECIBIDOBIZUMIMPUESTO RENTAQ2826000H100BKG*HOTEL AT BOOKFecha de operación: 24-06-2023Fecha de operación: 15-05-2023PREST. DESEMPLEOT.G.S.S. POR CUENTA SPEEFecha de operación: 01-11-2022Fecha de operación: 18-10-2022FGV ALICANTEFecha de operación: 14-10-2022Fecha de operación: 04-09-2022Fecha de operación: 22-08-2022REST. FALAFELMANIFecha de operación: 13-08-2022Fecha de operación: 06-08-2022Fecha de operación: 04-08-2022Fecha de operación: 28-07-2022ÿ:ËÅ!	b·	øq
#
# 5 ²^G
#
# 6 »
#
# 7 ÌÁ
#
# 8 dü©ñÒMbP?_*+%ÿÁ¡"d,,à?à?U}T}T}B}¸}î}	{ý
#
# 9 ý

# %% [markdown]
# In this case we'll try to read our `btc-market-price.csv` CSV file using different parameters to parse it correctly.
#
# This file contains records of the mean price of Bitcoin per date.

# %% [markdown]
# Or just use a local file:

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls')

df.head()

# %%
pd.read_excel('Movimientos_cuenta_0184491.xls').head()
# Out:
#   Movimientos de la cuenta ES25 2100 2809 1301 0018 4491 (CCC: 2100 2809 13 01 00184491)  \
# 0                       Importes expresados en euros
# 1                                              Fecha
# 2                                2024-03-15 00:00:00
# 3                                2024-03-11 00:00:00
# 4                                2024-03-08 00:00:00
#
#             Unnamed: 1          Unnamed: 2                      Unnamed: 3  \
# 0                  NaN                 NaN                             NaN
# 1          Fecha valor          Movimiento                       Más datos
# 2  2024-03-15 00:00:00   To Revolut -3FFH-      Az Eddine Derkaoui Chhibou
# 3  2024-03-11 00:00:00   HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024
# 4  2024-03-08 00:00:00  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou
#
#   Unnamed: 4 Unnamed: 5
# 0        NaN        NaN
# 1    Importe      Saldo
# 2       -200    27469.4
# 3         -6    27669.4
# 4          6    27675.4

# %%
df.tail()
# Out:
#     Movimientos de la cuenta ES25 2100 2809 1301 0018 4491 (CCC: 2100 2809 13 01 00184491)  \
# 117                                2022-08-08 00:00:00
# 118                                2022-08-07 00:00:00
# 119                                2022-08-07 00:00:00
# 120                                2022-08-04 00:00:00
# 121                                2022-08-01 00:00:00
#
#               Unnamed: 1        Unnamed: 2                      Unnamed: 3  \
# 117  2022-08-08 00:00:00  PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE
# 118  2022-08-07 00:00:00      REINT.CAJERO                             NaN
# 119  2022-08-07 00:00:00      REINT.CAJERO                             NaN
# 120  2022-08-04 00:00:00    PEPEMOBILE S.L              Recibo de teléfono
# 121  2022-08-01 00:00:00    Revolut**2175*  Fecha de operación: 28-07-2022
#
#     Unnamed: 4 Unnamed: 5
# 117    1083.16    32508.4
# 118        -20    31425.2
# 119       -310    31445.2
# 120      -7.81    31755.2
# 121        -50    31763.1

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=None)

# %%
df.head()
# Out:
#                                                    0                    1  \
# 0  Movimientos de la cuenta ES25 2100 2809 1301 0...                  NaN
# 1                       Importes expresados en euros                  NaN
# 2                                              Fecha          Fecha valor
# 3                                2024-03-15 00:00:00  2024-03-15 00:00:00
# 4                                2024-03-11 00:00:00  2024-03-11 00:00:00
#
#                    2                               3        4        5
# 0                NaN                             NaN      NaN      NaN
# 1                NaN                             NaN      NaN      NaN
# 2         Movimiento                       Más datos  Importe    Saldo
# 3  To Revolut -3FFH-      Az Eddine Derkaoui Chhibou     -200  27469.4
# 4  HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024       -6  27669.4

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=None,
                 na_values=['', '?', '-'])

# %%
df.head()
# Out:
#                                                    0                    1  \
# 0  Movimientos de la cuenta ES25 2100 2809 1301 0...                  NaN
# 1                       Importes expresados en euros                  NaN
# 2                                              Fecha          Fecha valor
# 3                                2024-03-15 00:00:00  2024-03-15 00:00:00
# 4                                2024-03-11 00:00:00  2024-03-11 00:00:00
#
#                    2                               3        4        5
# 0                NaN                             NaN      NaN      NaN
# 1                NaN                             NaN      NaN      NaN
# 2         Movimiento                       Más datos  Importe    Saldo
# 3  To Revolut -3FFH-      Az Eddine Derkaoui Chhibou     -200  27469.4
# 4  HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024       -6  27669.4

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Column names using `names` parameter
#
# We'll add that columns names using the `names` parameter.

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=None,
                 names=['Fecha', 'Fecha valor','Movimiento','Mas datos','Importe','Saldo'])

# %%
df.head()
# Out:
#                                                Fecha          Fecha valor  \
# 0  Movimientos de la cuenta ES25 2100 2809 1301 0...                  NaN
# 1                       Importes expresados en euros                  NaN
# 2                                              Fecha          Fecha valor
# 3                                2024-03-15 00:00:00  2024-03-15 00:00:00
# 4                                2024-03-11 00:00:00  2024-03-11 00:00:00
#
#           Movimiento                       Mas datos  Importe    Saldo
# 0                NaN                             NaN      NaN      NaN
# 1                NaN                             NaN      NaN      NaN
# 2         Movimiento                       Más datos  Importe    Saldo
# 3  To Revolut -3FFH-      Az Eddine Derkaoui Chhibou     -200  27469.4
# 4  HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024       -6  27669.4

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Column types using `dtype` parameter
#
#
# Without using the `dtype` parameter pandas will try to figure it out the type of each column automatically. We can use `dtype` parameter to force pandas to use certain dtype.
#
# In this case we'll force the `Price` column to be `float`.

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'})

# %%
df.head()
# Out:
#      Timestamp        Price
# 0  2/4/17 0:00  1099.169125
# 1  3/4/17 0:00  1141.813000
# 2  4/4/17 0:00          NaN
# 3  5/4/17 0:00  1133.079314
# 4  6/4/17 0:00          NaN

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %% [markdown]
# The `Timestamp` column was interpreted as a regular string (`object` in pandas notation), we can parse it manually using a vectorized operation as we saw on previous courses.
#
# We'll parse `Timestamp` column to `Datetime` objects using `to_datetime` method:

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2017-02-04
# 1   2017-03-04
# 2   2017-04-04
# 3   2017-05-04
# 4   2017-06-04
# Name: Timestamp, dtype: datetime64[ns]

# %%
pd.to_datetime(df['Fecha valor']).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\dev\python\installation\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-faccd512b5a7> in <module>
# ----> 1 pd.to_datetime(df['Fecha valor']).head()
#
# C:\dev\python\installation\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     449         else:
#     450             from pandas import Series
# --> 451             values = _convert_listlike(arg._values, True, format)
#     452             result = Series(values, index=arg.index, name=arg.name)
#     453     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# C:\dev\python\installation\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     379             except (ValueError, TypeError):
# --> 380                 raise e
#     381
#     382     if arg is None:
#
# C:\dev\python\installation\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     366                     dayfirst=dayfirst,
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#     370
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# C:\dev\python\installation\lib\site-packages\dateutil\parser\_parser.py in parse(timestr, parserinfo, **kwargs)
#    1354         return parser(parserinfo).parse(timestr, **kwargs)
#    1355     else:
# -> 1356         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1357
#    1358
#
# C:\dev\python\installation\lib\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     646
#     647         if res is None:
# --> 648             raise ValueError("Unknown string format:", timestr)
#     649
#     650         if len(res) == 0:
#
# ValueError: ('Unknown string format:', 'Fecha valor')

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-02-04  1099.169125
# 1 2017-03-04  1141.813000
# 2 2017-04-04          NaN
# 3 2017-05-04  1133.079314
# 4 2017-06-04          NaN

# %%
df.dtypes
# Out:
# Fecha valor    datetime64[ns]
# Movimiento             object
# Mas datos              object
# Importe               float64
# Saldo                 float64
# dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Date parser using `parse_dates` parameter
#
# Another way of dealing with `Datetime` objects is using `parse_dates` parameter with the position of the columns with dates.

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},
                 parse_dates=[0])

# %%
df.head()
# Out:
#    Timestamp        Price
# 0 2017-02-04  1099.169125
# 1 2017-03-04  1141.813000
# 2 2017-04-04          NaN
# 3 2017-05-04  1133.079314
# 4 2017-06-04          NaN

# %%
df.dtypes
# Out:
# Fecha valor    datetime64[ns]
# Movimiento             object
# Mas datos              object
# Importe               float64
# Saldo                 float64
# dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Adding index to our data using `index_col` parameter
#
# By default, pandas will automatically assign a numeric autoincremental index or row label starting with zero. You may want to leave the default index as such if your data doesn’t have a column with unique values that can serve as a better index. In case there is a column that you feel would serve as a better index, you can override the default behavior by setting `index_col` property to a column. It takes a numeric value representing the index or a string of the column name for setting a single column as index or a list of numeric values or strings for creating a multi-index.
#
# In our data, we are choosing the first column, `Timestamp`, as index (index=0) by passing zero to the `index_col` argument.

# %%
df = pd.read_csv('btc-market-price.csv',
                 header=None,
                 na_values=['', '?', '-'],
                 names=['Timestamp', 'Price'],
                 dtype={'Price': 'float'},
                 parse_dates=[0],
                 index_col=[0])

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=0,
                   skiprows=2,index_col=[0],
                   names=[ 'Fecha valor','Movimiento','Mas datos','Importe','Saldo'])

# %%
df.head()
# Out:
#            Fecha valor          Movimiento                       Mas datos  \
# Fecha
# 2024-03-15  2024-03-15   To Revolut -3FFH-      Az Eddine Derkaoui Chhibou
# 2024-03-11  2024-03-11   HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024
# 2024-03-08  2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou
# 2024-03-08  2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou
# 2024-03-08  2024-03-08        REINT.CAJERO                             NaN
#
#             Importe     Saldo
# Fecha
# 2024-03-15   -200.0  27469.36
# 2024-03-11     -6.0  27669.36
# 2024-03-08      6.0  27675.36
# 2024-03-08      7.0  27669.36
# 2024-03-08    -10.0  27662.36

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=0,
                   skiprows=2)

# %%
df.head()
# Out:
#        Fecha Fecha valor          Movimiento                       Más datos  \
# 0 2024-03-15  2024-03-15   To Revolut -3FFH-      Az Eddine Derkaoui Chhibou
# 1 2024-03-11  2024-03-11   HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024
# 2 2024-03-08  2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou
# 3 2024-03-08  2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou
# 4 2024-03-08  2024-03-08        REINT.CAJERO                             NaN
#
#    Importe     Saldo
# 0   -200.0  27469.36
# 1     -6.0  27669.36
# 2      6.0  27675.36
# 3      7.0  27669.36
# 4    -10.0  27662.36

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-848b80e64df8> in <module>
# ----> 1 df.plot()
#
# C:\dev\python\installation\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# C:\dev\python\installation\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# C:\dev\python\installation\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# C:\dev\python\installation\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     264
#     265         for ax in self.axes:
# --> 266             self._post_plot_logic_common(ax, self.data)
#     267             self._post_plot_logic(ax, self.data)
#     268
#
# C:\dev\python\installation\lib\site-packages\pandas\plotting\_core.py in _post_plot_logic_common(self, ax, data)
#     403             self._apply_axis_properties(ax.xaxis, rot=self.rot,
#     404                                         fontsize=self.fontsize)
# --> 405             self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     406
#     407             if hasattr(ax, 'right_ax'):
#
# C:\dev\python\installation\lib\site-packages\pandas\plotting\_core.py in _apply_axis_properties(self, axis, rot, fontsize)
#     476
#     477     def _apply_axis_properties(self, axis, rot=None, fontsize=None):
# --> 478         labels = axis.get_majorticklabels() + axis.get_minorticklabels()
#     479         for label in labels:
#     480             if rot is not None:
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1389         'get the tick instances; grow as necessary'
#    1390         if numticks is None:
# -> 1391             numticks = len(self.get_major_locator()())
#    1392
#    1393         while len(self.majorTicks) < numticks:
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1228     def __call__(self):
#    1229         'Return the locations of the ticks'
# -> 1230         self.refresh()
#    1231         return self._locator()
#    1232
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in refresh(self)
#    1248     def refresh(self):
#    1249         'Refresh internal information based on current limits.'
# -> 1250         dmin, dmax = self.viewlim_to_dt()
#    1251         self._locator = self.get_locator(dmin, dmax)
#    1252
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#     999                              'often happens if you pass a non-datetime '
#    1000                              'value to an axis that has datetime units'
# -> 1001                              .format(vmin))
#    1002         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1003
#
# ValueError: view limit minimum -37791.234000000004 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000216A7F53840> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\dev\python\installation\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# C:\dev\python\installation\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# C:\dev\python\installation\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# C:\dev\python\installation\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# C:\dev\python\installation\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\dev\python\installation\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# C:\dev\python\installation\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\dev\python\installation\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# C:\dev\python\installation\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# C:\dev\python\installation\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1183         renderer.open_group(__name__)
#    1184
# -> 1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1187                                                                 renderer)
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in iter_ticks(self)
#     965         Iterate through all of the major and minor ticks.
#     966         """
# --> 967         majorLocs = self.major.locator()
#     968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1228     def __call__(self):
#    1229         'Return the locations of the ticks'
# -> 1230         self.refresh()
#    1231         return self._locator()
#    1232
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in refresh(self)
#    1248     def refresh(self):
#    1249         'Refresh internal information based on current limits.'
# -> 1250         dmin, dmax = self.viewlim_to_dt()
#    1251         self._locator = self.get_locator(dmin, dmax)
#    1252
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#     999                              'often happens if you pass a non-datetime '
#    1000                              'value to an axis that has datetime units'
# -> 1001                              .format(vmin))
#    1002         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1003
#
# ValueError: view limit minimum -37791.234000000004 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\dev\python\installation\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# C:\dev\python\installation\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# C:\dev\python\installation\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1284         if minor:
#    1285             return self.get_minorticklabels()
# -> 1286         return self.get_majorticklabels()
#    1287
#    1288     def get_majorticklines(self):
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# C:\dev\python\installation\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1389         'get the tick instances; grow as necessary'
#    1390         if numticks is None:
# -> 1391             numticks = len(self.get_major_locator()())
#    1392
#    1393         while len(self.majorTicks) < numticks:
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1228     def __call__(self):
#    1229         'Return the locations of the ticks'
# -> 1230         self.refresh()
#    1231         return self._locator()
#    1232
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in refresh(self)
#    1248     def refresh(self):
#    1249         'Refresh internal information based on current limits.'
# -> 1250         dmin, dmax = self.viewlim_to_dt()
#    1251         self._locator = self.get_locator(dmin, dmax)
#    1252
#
# C:\dev\python\installation\lib\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#     999                              'often happens if you pass a non-datetime '
#    1000                              'value to an axis that has datetime units'
# -> 1001                              .format(vmin))
#    1002         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1003
#
# ValueError: view limit minimum -37791.234000000004 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
import matplotlib.pyplot as plt
plt.plot(df['Fecha valor'], df['Importe'])
plt.figure(figsize=(480, 1200))
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000216A7F53840> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\dev\python\installation\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# C:\dev\python\installation\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# C:\dev\python\installation\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# C:\dev\python\installation\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     394         Draw the figure using the renderer.
#     395         """
# --> 396         self.renderer = self.get_renderer(cleared=True)
#     397         # acquire a lock on the shared font cache
#     398         RendererAgg.lock.acquire()
#
# C:\dev\python\installation\lib\site-packages\matplotlib\backends\backend_agg.py in get_renderer(self, cleared)
#     415
#     416         if need_new_renderer:
# --> 417             self.renderer = RendererAgg(w, h, self.figure.dpi)
#     418             self._lastKey = key
#     419         elif cleared:
#
# C:\dev\python\installation\lib\site-packages\matplotlib\backends\backend_agg.py in __init__(self, width, height, dpi)
#      85         self.width = width
#      86         self.height = height
# ---> 87         self._renderer = _RendererAgg(int(width), int(height), dpi)
#      88         self._filter_renderers = []
#      89
#
# ValueError: Image size of 34560x86400 pixels is too large. It must be less than 2^16 in each direction.

# %%
df.columns
# Out:
# Index(['Fecha', 'Fecha valor', 'Movimiento', 'Más datos', 'Importe', 'Saldo'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2024-03-15', '2024-03-11', '2024-03-08', '2024-03-08',
#                '2024-03-08', '2024-03-04', '2024-02-07', '2024-02-07',
#                '2024-02-05', '2024-01-18',
#                ...
#                '2022-08-26', '2022-08-25', '2022-08-17', '2022-08-10',
#                '2022-08-08', '2022-08-08', '2022-08-07', '2022-08-07',
#                '2022-08-04', '2022-08-01'],
#               dtype='datetime64[ns]', name='Fecha', length=120, freq=None)

# %%
df.size
# Out:
# 600

# %%
df.shape
# Out:
# (120, 5)

# %%
df.describe()
# Out:
#            Importe         Saldo
# count   120.000000    120.000000
# mean    -36.197500  32428.591667
# std     355.406129   2189.826511
# min    -803.080000  27469.360000
# 25%    -200.000000  31424.872500
# 50%     -44.100000  32775.030000
# 75%      -6.900000  34058.370000
# max    1083.160000  35585.660000

# %%
df['Fecha']
# Out:
# 0     2024-03-15
# 1     2024-03-11
# 2     2024-03-08
# 3     2024-03-08
# 4     2024-03-08
# 5     2024-03-04
# 6     2024-02-07
# 7     2024-02-07
# 8     2024-02-05
# 9     2024-01-18
# 10    2024-01-17
# 11    2024-01-08
# 12    2024-01-08
# 13    2024-01-04
# 14    2023-12-04
# 15    2023-12-04
# 16    2023-12-04
# 17    2023-11-13
# 18    2023-10-27
# 19    2023-10-06
# 20    2023-10-04
# 21    2023-10-04
# 22    2023-10-03
# 23    2023-09-29
# 24    2023-09-10
# 25    2023-09-06
# 26    2023-09-05
# 27    2023-08-25
# 28    2023-08-24
# 29    2023-08-07
#          ...
# 90    2022-11-10
# 91    2022-11-07
# 92    2022-11-05
# 93    2022-11-03
# 94    2022-11-01
# 95    2022-10-22
# 96    2022-10-18
# 97    2022-10-17
# 98    2022-10-08
# 99    2022-10-08
# 100   2022-10-04
# 101   2022-10-04
# 102   2022-09-23
# 103   2022-09-09
# 104   2022-09-09
# 105   2022-09-08
# 106   2022-09-06
# 107   2022-09-05
# 108   2022-09-03
# 109   2022-08-26
# 110   2022-08-26
# 111   2022-08-25
# 112   2022-08-17
# 113   2022-08-10
# 114   2022-08-08
# 115   2022-08-08
# 116   2022-08-07
# 117   2022-08-07
# 118   2022-08-04
# 119   2022-08-01
# Name: Fecha, Length: 120, dtype: datetime64[ns]

# %%
df[['Fecha','Movimiento','Importe']]
# Out:
#          Fecha          Movimiento  Importe
# 0   2024-03-15   To Revolut -3FFH-  -200.00
# 1   2024-03-11   HOTEL TRYP GRAN S    -6.00
# 2   2024-03-08  TRANSFER INMEDIATA     6.00
# 3   2024-03-08  TRANSFER INMEDIATA     7.00
# 4   2024-03-08        REINT.CAJERO   -10.00
# 5   2024-03-04        REINT.CAJERO  -330.00
# 6   2024-02-07       BIZUM ENVIADO    -7.50
# 7   2024-02-07       BIZUM ENVIADO   -20.50
# 8   2024-02-05        REINT.CAJERO  -330.00
# 9   2024-01-18        REINT.CAJERO   -10.00
# 10  2024-01-17   To Revolut -O5J1-  -300.00
# 11  2024-01-08        REINT.CAJERO   -10.00
# 12  2024-01-08        REINT.CAJERO  -320.00
# 13  2024-01-04      UGT PAIS VALEN   -45.60
# 14  2023-12-04        REINT.CAJERO   -50.00
# 15  2023-12-04      INGRESO CAJERO    50.00
# 16  2023-12-04        REINT.CAJERO  -350.00
# 17  2023-11-13        REINT.CAJERO  -320.00
# 18  2023-10-27    Gastos Mensuales  -300.00
# 19  2023-10-06        REINT.CAJERO  -310.00
# 20  2023-10-04   TRF.INTERNACIONAL  -200.00
# 21  2023-10-04      UGT PAIS VALEN   -44.10
# 22  2023-10-03      PEPEMOBILE S.L    -7.90
# 23  2023-09-29      Revolut**2175*  -225.00
# 24  2023-09-10   TRF.INTERNACIONAL  -200.00
# 25  2023-09-06        REINT.CAJERO  -310.00
# 26  2023-09-05      PEPEMOBILE S.L    -7.08
# 27  2023-08-25       BIZUM ENVIADO    -3.70
# 28  2023-08-24   TRF.INTERNACIONAL  -100.00
# 29  2023-08-07        REINT.CAJERO  -310.00
# ..         ...                 ...      ...
# 90  2022-11-10    PREST. DESEMPLEO  1083.16
# 91  2022-11-07        REINT.CAJERO  -310.00
# 92  2022-11-05      Revolut**2175*   -10.00
# 93  2022-11-03      PEPEMOBILE S.L    -8.22
# 94  2022-11-01   TRF.INTERNACIONAL  -200.00
# 95  2022-10-22      Revolut**2175*   -10.00
# 96  2022-10-18   TRF.INTERNACIONAL  -100.00
# 97  2022-10-17        FGV ALICANTE   -12.10
# 98  2022-10-08        REINT.CAJERO  -310.00
# 99  2022-10-08    PREST. DESEMPLEO  1083.16
# 100 2022-10-04      UGT PAIS VALEN   -42.60
# 101 2022-10-04      PEPEMOBILE S.L    -7.26
# 102 2022-09-23   TRF.INTERNACIONAL  -200.00
# 103 2022-09-09      Revolut**2175*   -10.00
# 104 2022-09-09      Revolut**2175*   -10.00
# 105 2022-09-08    PREST. DESEMPLEO  1083.16
# 106 2022-09-06        REINT.CAJERO  -310.00
# 107 2022-09-05      PEPEMOBILE S.L    -7.44
# 108 2022-09-03   TRF.INTERNACIONAL  -200.00
# 109 2022-08-26   TRF.INTERNACIONAL   -50.00
# 110 2022-08-26      Revolut**2175*   -50.00
# 111 2022-08-25   REST. FALAFELMANI   -34.10
# 112 2022-08-17      Revolut**2175*   -50.00
# 113 2022-08-10      Revolut**2175*   -50.00
# 114 2022-08-08      Revolut**2175*   -50.00
# 115 2022-08-08    PREST. DESEMPLEO  1083.16
# 116 2022-08-07        REINT.CAJERO   -20.00
# 117 2022-08-07        REINT.CAJERO  -310.00
# 118 2022-08-04      PEPEMOBILE S.L    -7.81
# 119 2022-08-01      Revolut**2175*   -50.00
#
# [120 rows x 3 columns]

# %%
df.dtypes
# Out:
# Fecha valor    datetime64[ns]
# Movimiento             object
# Mas datos              object
# Importe               float64
# Saldo                 float64
# dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## A more challenging parsing
#
# Now we'll read another CSV file. This file has the following columns:
#
# - `first_name`
# - `last_name`
# - `age`
# - `math_score`
# - `french_score`
# - `next_test_date`
#
# Let's read it and see how it looks like.

# %%
exam_df = pd.read_csv('exam_review.csv')

# %%
exam_df
# Out:
#                                first_name>last_name>age>math_score>french_score
# Ray>Morley>18>"68     000">"75                                             000"
# Melvin>Scott>24>77>83 NaN                                                   NaN
# Amirah>Haley>22>92>67 NaN                                                   NaN
# Gerard>Mills>19>"78   000">72                                               NaN
# Amy>Grimes>23>91>81   NaN                                                   NaN

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Custom data delimiters using `sep` parameter
#
# We can define which delimiter to use by using the `sep` parameter. If we don't use the `sep` parameter, pandas will automatically detect the separator.
#
# In most of the CSV files separator will be comma (`,`) and will be automatically detected. But we can find files with other separators like semicolon (`;`), tabs (`\t`, specially on TSV files), whitespaces or any other special character.
#
# In this case the separator is a `>` character.

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>')

# %%
exam_df
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Custom data encoding
#
# Files are stored using different "encodings". You've probably heard about ASCII, UTF-8, latin1, etc.
#
# While reading data custom encoding can be defined with the `encoding` parameter.
#
# - `encoding='UTF-8'`: will be used if data is UTF-8 encoded.
# - `encoding='iso-8859-1'`: will be used if data is ISO/IEC 8859-1 ("extended ASCII") encoded.
#
# In our case we don't need a custom enconding as data is properly loaded.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Custom numeric `decimal` and `thousands` character
#
# The decimal and thousands characters could change between datasets. If we have a column containing a comma (`,`) to indicate the decimal or thousands place, then this column would be considered a string and not numeric.

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>')

# %%
exam_df
# Out:
#   first_name last_name  age math_score french_score
# 0        Ray    Morley   18     68,000       75,000
# 1     Melvin     Scott   24         77           83
# 2     Amirah     Haley   22         92           67
# 3     Gerard     Mills   19     78,000           72
# 4        Amy    Grimes   23         91           81

# %%
exam_df[['math_score', 'french_score']].dtypes
# Out:
# math_score      object
# french_score    object
# dtype: object

# %% [markdown]
# To solve that, ensuring such columns are interpreted as integer values, we'll need to use the `decimal` and/or `thousands` parameters to indicate correct decimal and/or thousands indicators.

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>',
                      decimal=',')

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %%
exam_df[['math_score', 'french_score']].dtypes
# Out:
# math_score      float64
# french_score    float64
# dtype: object

# %% [markdown]
# Let's see what happens with the `thousands` parameter:

# %%
pd.read_csv('exam_review.csv',
            sep='>',
            thousands=',')
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18       68000         75000
# 1     Melvin     Scott   24          77            83
# 2     Amirah     Haley   22          92            67
# 3     Gerard     Mills   19       78000            72
# 4        Amy    Grimes   23          91            81

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Excluding specific rows
#
# We can use the `skiprows` to:
#
# - Exclude reading specified number of rows from the beginning of a file, by passing an integer argument. **This removes the header too**.
# - Skip reading specific row indices from a file, by passing a list containing row indices to skip.

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>',
                      decimal=',')

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0        Ray    Morley   18        68.0          75.0
# 1     Melvin     Scott   24        77.0          83.0
# 2     Amirah     Haley   22        92.0          67.0
# 3     Gerard     Mills   19        78.0          72.0
# 4        Amy    Grimes   23        91.0          81.0

# %% [markdown]
# To skip reading the first 2 rows from this file, we can use `skiprows=2`:

# %%
pd.read_csv('exam_review.csv',
            sep='>',
            skiprows=2)
# Out:
#    Melvin   Scott  24      77  83
# 0  Amirah   Haley  22      92  67
# 1  Gerard   Mills  19  78,000  72
# 2     Amy  Grimes  23      91  81

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=0,
                   skiprows=2)

# %%
df.head()
# Out:
#        Fecha Fecha valor          Movimiento                       Más datos  \
# 0 2024-03-15  2024-03-15   To Revolut -3FFH-      Az Eddine Derkaoui Chhibou
# 1 2024-03-11  2024-03-11   HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024
# 2 2024-03-08  2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou
# 3 2024-03-08  2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou
# 4 2024-03-08  2024-03-08        REINT.CAJERO                             NaN
#
#    Importe     Saldo
# 0   -200.0  27469.36
# 1     -6.0  27669.36
# 2      6.0  27675.36
# 3      7.0  27669.36
# 4    -10.0  27662.36

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 6 columns):
# Fecha          120 non-null datetime64[ns]
# Fecha valor    120 non-null datetime64[ns]
# Movimiento     120 non-null object
# Más datos      87 non-null object
# Importe        120 non-null float64
# Saldo          120 non-null float64
# dtypes: datetime64[ns](2), float64(2), object(2)
# memory usage: 5.7+ KB

# %% [markdown]
# As the header is considered as the first row, to skip reading data rows 1 and 3, we can use `skiprows=[1,3]`:

# %%
exam_df = pd.read_csv('exam_review.csv',
                      sep='>',
                      decimal=',',
                      skiprows=[1,3])

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0     Melvin     Scott   24        77.0            83
# 1     Gerard     Mills   19        78.0            72
# 2        Amy    Grimes   23        91.0            81

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Get rid of blank lines
#
# The `skip_blank_lines` parameter is set to `True` so blank lines are skipped while we read files.
#
# If we set this parameter to `False`, then every blank line will be loaded with `NaN` values into the `DataFrame`.

# %%
pd.read_csv('exam_review.csv',
            sep='>',
            skip_blank_lines=False)
# Out:
#   first_name last_name   age math_score french_score
# 0        Ray    Morley  18.0     68,000       75,000
# 1     Melvin     Scott  24.0         77           83
# 2     Amirah     Haley  22.0         92           67
# 3        NaN       NaN   NaN        NaN          NaN
# 4     Gerard     Mills  19.0     78,000           72
# 5        Amy    Grimes  23.0         91           81

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Loading specific columns
#
# We can use the `usecols` parameter when we want to load just specific columns and not all of them.
#
# Performance wise, it is better because instead of loading an entire dataframe into memory and then deleting the not required columns, we can select the columns that we’ll need, while loading the dataset itself.
#
# As a parameter to `usecols`, you can pass either a list of strings corresponding to the column names or a list of integers corresponding to column index.

# %%
pd.read_csv('exam_review.csv',
            usecols=['first_name', 'last_name', 'age'],
            sep='>')
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=0,
                   skiprows=2,usecols=[0,2,4])

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=0,
                   skiprows=2, 
                   names=['Fecha', 'Fecha valor','Movimiento','Mas datos','Importe','Saldo'],
                   usecols=['Fecha','Valor'])

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=0,
                   skiprows=2,usecols=[0])

# %%
df.head()
# Out:
#        Fecha          Movimiento  Importe
# 0 2024-03-15   To Revolut -3FFH-   -200.0
# 1 2024-03-11   HOTEL TRYP GRAN S     -6.0
# 2 2024-03-08  TRANSFER INMEDIATA      6.0
# 3 2024-03-08  TRANSFER INMEDIATA      7.0
# 4 2024-03-08        REINT.CAJERO    -10.0

# %% [markdown]
# Or using just the column position:

# %%
pd.read_csv('exam_review.csv',
            usecols=[0, 1, 2],
            sep='>')
# Out:
#   first_name last_name  age
# 0        Ray    Morley   18
# 1     Melvin     Scott   24
# 2     Amirah     Haley   22
# 3     Gerard     Mills   19
# 4        Amy    Grimes   23

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Using a `Series` instead of `DataFrame`
#
# If the parsed data only contains one column then we can return a Series by setting the `squeeze` parameter to `True`.

# %%
exam_test_1 = pd.read_csv('exam_review.csv',
                          sep='>',
                          usecols=['last_name'])

# %%
type(exam_test_1)
# Out:
# pandas.core.frame.DataFrame

# %%
exam_test_2 = pd.read_csv('exam_review.csv',
                          sep='>',
                          usecols=['last_name'],
                          squeeze=True)

# %%
type(exam_test_2)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ## Save to CSV file
#
# Finally we can also save our `DataFrame` as a CSV file.

# %%
exam_df
# Out:
#   first_name last_name  age  math_score  french_score
# 0     Melvin     Scott   24        77.0            83
# 1     Gerard     Mills   19        78.0            72
# 2        Amy    Grimes   23        91.0            81

# %% [markdown]
# We can simply generate a CSV string from our `DataFrame`:

# %%
exam_df.to_csv()
# Out:
# ',first_name,last_name,age,math_score,french_score\n0,Melvin,Scott,24,77.0,83\n1,Gerard,Mills,19,78.0,72\n2,Amy,Grimes,23,91.0,81\n'

# %%
df.to_csv()
# Out:
# ',Fecha\n0,2024-03-15\n1,2024-03-11\n2,2024-03-08\n3,2024-03-08\n4,2024-03-08\n5,2024-03-04\n6,2024-02-07\n7,2024-02-07\n8,2024-02-05\n9,2024-01-18\n10,2024-01-17\n11,2024-01-08\n12,2024-01-08\n13,2024-01-04\n14,2023-12-04\n15,2023-12-04\n16,2023-12-04\n17,2023-11-13\n18,2023-10-27\n19,2023-10-06\n20,2023-10-04\n21,2023-10-04\n22,2023-10-03\n23,2023-09-29\n24,2023-09-10\n25,2023-09-06\n26,2023-09-05\n27,2023-08-25\n28,2023-08-24\n29,2023-08-07\n30,2023-08-03\n31,2023-07-29\n32,2023-07-21\n33,2023-07-20\n34,2023-07-19\n35,2023-07-18\n36,2023-07-14\n37,2023-07-08\n38,2023-07-05\n39,2023-07-04\n40,2023-06-30\n41,2023-06-29\n42,2023-06-25\n43,2023-06-23\n44,2023-06-21\n45,2023-06-05\n46,2023-06-05\n47,2023-06-01\n48,2023-05-19\n49,2023-05-05\n50,2023-05-03\n51,2023-04-27\n52,2023-04-19\n53,2023-04-18\n54,2023-04-10\n55,2023-04-10\n56,2023-04-06\n57,2023-04-05\n58,2023-04-04\n59,2023-04-04\n60,2023-04-02\n61,2023-04-02\n62,2023-03-17\n63,2023-03-13\n64,2023-03-13\n65,2023-03-10\n66,2023-03-07\n67,2023-03-03\n68,2023-02-10\n69,2023-02-08\n70,2023-02-08\n71,2023-02-06\n72,2023-02-06\n73,2023-02-04\n74,2023-02-03\n75,2023-02-01\n76,2023-01-27\n77,2023-01-10\n78,2023-01-08\n79,2023-01-04\n80,2023-01-04\n81,2022-12-27\n82,2022-12-10\n83,2022-12-08\n84,2022-12-05\n85,2022-12-05\n86,2022-11-26\n87,2022-11-13\n88,2022-11-13\n89,2022-11-11\n90,2022-11-10\n91,2022-11-07\n92,2022-11-05\n93,2022-11-03\n94,2022-11-01\n95,2022-10-22\n96,2022-10-18\n97,2022-10-17\n98,2022-10-08\n99,2022-10-08\n100,2022-10-04\n101,2022-10-04\n102,2022-09-23\n103,2022-09-09\n104,2022-09-09\n105,2022-09-08\n106,2022-09-06\n107,2022-09-05\n108,2022-09-03\n109,2022-08-26\n110,2022-08-26\n111,2022-08-25\n112,2022-08-17\n113,2022-08-10\n114,2022-08-08\n115,2022-08-08\n116,2022-08-07\n117,2022-08-07\n118,2022-08-04\n119,2022-08-01\n'

# %% [markdown]
# Or specify a file path where we want our generated CSV code to be saved:

# %%
exam_df.to_csv('out.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-26944ce932db> in <module>
# ----> 1 exam_df.to_csv('out.csv')
#
# NameError: name 'exam_df' is not defined

# %%
df.to_csv('out.csv')

# %%
pd.read_csv('out.csv')
# Out:
#    Unnamed: 0 first_name last_name  age  math_score  french_score
# 0           0     Melvin     Scott   24        77.0            83
# 1           1     Gerard     Mills   19        78.0            72
# 2           2        Amy    Grimes   23        91.0            81

# %%
exam_df.to_csv('out.csv',
               index=None)

# %%
df = pd.read_excel('Movimientos_cuenta_0184491.xls',
                 header=0,
                   skiprows=2,usecols=[0,4,2,3,5])

# %%
df.head()
# Out:
#        Fecha          Movimiento                       Más datos  Importe  \
# 0 2024-03-15   To Revolut -3FFH-      Az Eddine Derkaoui Chhibou   -200.0
# 1 2024-03-11   HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024     -6.0
# 2 2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou      6.0
# 3 2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou      7.0
# 4 2024-03-08        REINT.CAJERO                             NaN    -10.0
#
#       Saldo
# 0  27469.36
# 1  27669.36
# 2  27675.36
# 3  27669.36
# 4  27662.36

# %%
df.to_csv('out.csv',index=None)

# %%
df.to_excel('out.xls',index=None)

# %%
pd.read_excel('out.xls')
# Out:
#          Fecha          Movimiento                       Más datos  Importe  \
# 0   2024-03-15   To Revolut -3FFH-      Az Eddine Derkaoui Chhibou  -200.00
# 1   2024-03-11   HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024    -6.00
# 2   2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou     6.00
# 3   2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou     7.00
# 4   2024-03-08        REINT.CAJERO                             NaN   -10.00
# 5   2024-03-04        REINT.CAJERO                             NaN  -330.00
# 6   2024-02-07       BIZUM ENVIADO                             NaN    -7.50
# 7   2024-02-07       BIZUM ENVIADO                             NaN   -20.50
# 8   2024-02-05        REINT.CAJERO                             NaN  -330.00
# 9   2024-01-18        REINT.CAJERO                             NaN   -10.00
# 10  2024-01-17   To Revolut -O5J1-      Az Eddine Derkaoui Chhibou  -300.00
# 11  2024-01-08        REINT.CAJERO                             NaN   -10.00
# 12  2024-01-08        REINT.CAJERO                             NaN  -320.00
# 13  2024-01-04      UGT PAIS VALEN                    G46949863002   -45.60
# 14  2023-12-04        REINT.CAJERO                             NaN   -50.00
# 15  2023-12-04      INGRESO CAJERO              ERROR SACAR DINERO    50.00
# 16  2023-12-04        REINT.CAJERO                             NaN  -350.00
# 17  2023-11-13        REINT.CAJERO                             NaN  -320.00
# 18  2023-10-27    Gastos Mensuales              Az Eddine Derkaoui  -300.00
# 19  2023-10-06        REINT.CAJERO                             NaN  -310.00
# 20  2023-10-04   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 21  2023-10-04      UGT PAIS VALEN                    G46949863002   -44.10
# 22  2023-10-03      PEPEMOBILE S.L              Recibo de teléfono    -7.90
# 23  2023-09-29      Revolut**2175*  Fecha de operación: 25-09-2023  -225.00
# 24  2023-09-10   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 25  2023-09-06        REINT.CAJERO                             NaN  -310.00
# 26  2023-09-05      PEPEMOBILE S.L              Recibo de teléfono    -7.08
# 27  2023-08-25       BIZUM ENVIADO                             NaN    -3.70
# 28  2023-08-24   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -100.00
# 29  2023-08-07        REINT.CAJERO                             NaN  -310.00
# ..         ...                 ...                             ...      ...
# 90  2022-11-10    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 91  2022-11-07        REINT.CAJERO                             NaN  -310.00
# 92  2022-11-05      Revolut**2175*  Fecha de operación: 01-11-2022   -10.00
# 93  2022-11-03      PEPEMOBILE S.L              Recibo de teléfono    -8.22
# 94  2022-11-01   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 95  2022-10-22      Revolut**2175*  Fecha de operación: 18-10-2022   -10.00
# 96  2022-10-18   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -100.00
# 97  2022-10-17        FGV ALICANTE  Fecha de operación: 14-10-2022   -12.10
# 98  2022-10-08        REINT.CAJERO                             NaN  -310.00
# 99  2022-10-08    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 100 2022-10-04      UGT PAIS VALEN                    G46949863002   -42.60
# 101 2022-10-04      PEPEMOBILE S.L              Recibo de teléfono    -7.26
# 102 2022-09-23   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 103 2022-09-09      Revolut**2175*  Fecha de operación: 04-09-2022   -10.00
# 104 2022-09-09      Revolut**2175*  Fecha de operación: 04-09-2022   -10.00
# 105 2022-09-08    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 106 2022-09-06        REINT.CAJERO                             NaN  -310.00
# 107 2022-09-05      PEPEMOBILE S.L              Recibo de teléfono    -7.44
# 108 2022-09-03   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 109 2022-08-26   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU   -50.00
# 110 2022-08-26      Revolut**2175*  Fecha de operación: 22-08-2022   -50.00
# 111 2022-08-25   REST. FALAFELMANI  Fecha de operación: 22-08-2022   -34.10
# 112 2022-08-17      Revolut**2175*  Fecha de operación: 13-08-2022   -50.00
# 113 2022-08-10      Revolut**2175*  Fecha de operación: 06-08-2022   -50.00
# 114 2022-08-08      Revolut**2175*  Fecha de operación: 04-08-2022   -50.00
# 115 2022-08-08    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 116 2022-08-07        REINT.CAJERO                             NaN   -20.00
# 117 2022-08-07        REINT.CAJERO                             NaN  -310.00
# 118 2022-08-04      PEPEMOBILE S.L              Recibo de teléfono    -7.81
# 119 2022-08-01      Revolut**2175*  Fecha de operación: 28-07-2022   -50.00
#
#         Saldo
# 0    27469.36
# 1    27669.36
# 2    27675.36
# 3    27669.36
# 4    27662.36
# 5    27672.36
# 6    28002.36
# 7    28009.86
# 8    28030.36
# 9    28360.36
# 10   28370.36
# 11   28670.36
# 12   28680.36
# 13   29000.36
# 14   29045.96
# 15   29095.96
# 16   29045.96
# 17   29395.96
# 18   29715.96
# 19   30015.96
# 20   30325.96
# 21   30525.96
# 22   30570.06
# 23   30577.96
# 24   30802.96
# 25   31002.96
# 26   31312.96
# 27   31320.04
# 28   31323.74
# 29   31423.74
# ..        ...
# 90   33726.17
# 91   32643.01
# 92   32953.01
# 93   32963.01
# 94   32971.23
# 95   33171.23
# 96   33181.23
# 97   33281.23
# 98   33293.33
# 99   33603.33
# 100  32520.17
# 101  32562.77
# 102  32570.03
# 103  32770.03
# 104  32780.03
# 105  32790.03
# 106  31706.87
# 107  32016.87
# 108  32024.31
# 109  32224.31
# 110  32274.31
# 111  32324.31
# 112  32358.41
# 113  32408.41
# 114  32458.41
# 115  32508.41
# 116  31425.25
# 117  31445.25
# 118  31755.25
# 119  31763.06
#
# [120 rows x 5 columns]

# %%
pd.read_csv('out.csv')
# Out:
#           Fecha          Movimiento                       Más datos  Importe  \
# 0    2024-03-15   To Revolut -3FFH-      Az Eddine Derkaoui Chhibou  -200.00
# 1    2024-03-11   HOTEL TRYP GRAN S  Fecha de operación: 08-03-2024    -6.00
# 2    2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou     6.00
# 3    2024-03-08  TRANSFER INMEDIATA      Az Eddine Derkaoui Chhibou     7.00
# 4    2024-03-08        REINT.CAJERO                             NaN   -10.00
# 5    2024-03-04        REINT.CAJERO                             NaN  -330.00
# 6    2024-02-07       BIZUM ENVIADO                             NaN    -7.50
# 7    2024-02-07       BIZUM ENVIADO                             NaN   -20.50
# 8    2024-02-05        REINT.CAJERO                             NaN  -330.00
# 9    2024-01-18        REINT.CAJERO                             NaN   -10.00
# 10   2024-01-17   To Revolut -O5J1-      Az Eddine Derkaoui Chhibou  -300.00
# 11   2024-01-08        REINT.CAJERO                             NaN   -10.00
# 12   2024-01-08        REINT.CAJERO                             NaN  -320.00
# 13   2024-01-04      UGT PAIS VALEN                    G46949863002   -45.60
# 14   2023-12-04        REINT.CAJERO                             NaN   -50.00
# 15   2023-12-04      INGRESO CAJERO              ERROR SACAR DINERO    50.00
# 16   2023-12-04        REINT.CAJERO                             NaN  -350.00
# 17   2023-11-13        REINT.CAJERO                             NaN  -320.00
# 18   2023-10-27    Gastos Mensuales              Az Eddine Derkaoui  -300.00
# 19   2023-10-06        REINT.CAJERO                             NaN  -310.00
# 20   2023-10-04   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 21   2023-10-04      UGT PAIS VALEN                    G46949863002   -44.10
# 22   2023-10-03      PEPEMOBILE S.L              Recibo de teléfono    -7.90
# 23   2023-09-29      Revolut**2175*  Fecha de operación: 25-09-2023  -225.00
# 24   2023-09-10   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 25   2023-09-06        REINT.CAJERO                             NaN  -310.00
# 26   2023-09-05      PEPEMOBILE S.L              Recibo de teléfono    -7.08
# 27   2023-08-25       BIZUM ENVIADO                             NaN    -3.70
# 28   2023-08-24   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -100.00
# 29   2023-08-07        REINT.CAJERO                             NaN  -310.00
# ..          ...                 ...                             ...      ...
# 90   2022-11-10    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 91   2022-11-07        REINT.CAJERO                             NaN  -310.00
# 92   2022-11-05      Revolut**2175*  Fecha de operación: 01-11-2022   -10.00
# 93   2022-11-03      PEPEMOBILE S.L              Recibo de teléfono    -8.22
# 94   2022-11-01   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 95   2022-10-22      Revolut**2175*  Fecha de operación: 18-10-2022   -10.00
# 96   2022-10-18   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -100.00
# 97   2022-10-17        FGV ALICANTE  Fecha de operación: 14-10-2022   -12.10
# 98   2022-10-08        REINT.CAJERO                             NaN  -310.00
# 99   2022-10-08    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 100  2022-10-04      UGT PAIS VALEN                    G46949863002   -42.60
# 101  2022-10-04      PEPEMOBILE S.L              Recibo de teléfono    -7.26
# 102  2022-09-23   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 103  2022-09-09      Revolut**2175*  Fecha de operación: 04-09-2022   -10.00
# 104  2022-09-09      Revolut**2175*  Fecha de operación: 04-09-2022   -10.00
# 105  2022-09-08    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 106  2022-09-06        REINT.CAJERO                             NaN  -310.00
# 107  2022-09-05      PEPEMOBILE S.L              Recibo de teléfono    -7.44
# 108  2022-09-03   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU  -200.00
# 109  2022-08-26   TRF.INTERNACIONAL      AZ EDDINE DERKAOUI CHHIBOU   -50.00
# 110  2022-08-26      Revolut**2175*  Fecha de operación: 22-08-2022   -50.00
# 111  2022-08-25   REST. FALAFELMANI  Fecha de operación: 22-08-2022   -34.10
# 112  2022-08-17      Revolut**2175*  Fecha de operación: 13-08-2022   -50.00
# 113  2022-08-10      Revolut**2175*  Fecha de operación: 06-08-2022   -50.00
# 114  2022-08-08      Revolut**2175*  Fecha de operación: 04-08-2022   -50.00
# 115  2022-08-08    PREST. DESEMPLEO        T.G.S.S. POR CUENTA SPEE  1083.16
# 116  2022-08-07        REINT.CAJERO                             NaN   -20.00
# 117  2022-08-07        REINT.CAJERO                             NaN  -310.00
# 118  2022-08-04      PEPEMOBILE S.L              Recibo de teléfono    -7.81
# 119  2022-08-01      Revolut**2175*  Fecha de operación: 28-07-2022   -50.00
#
#         Saldo
# 0    27469.36
# 1    27669.36
# 2    27675.36
# 3    27669.36
# 4    27662.36
# 5    27672.36
# 6    28002.36
# 7    28009.86
# 8    28030.36
# 9    28360.36
# 10   28370.36
# 11   28670.36
# 12   28680.36
# 13   29000.36
# 14   29045.96
# 15   29095.96
# 16   29045.96
# 17   29395.96
# 18   29715.96
# 19   30015.96
# 20   30325.96
# 21   30525.96
# 22   30570.06
# 23   30577.96
# 24   30802.96
# 25   31002.96
# 26   31312.96
# 27   31320.04
# 28   31323.74
# 29   31423.74
# ..        ...
# 90   33726.17
# 91   32643.01
# 92   32953.01
# 93   32963.01
# 94   32971.23
# 95   33171.23
# 96   33181.23
# 97   33281.23
# 98   33293.33
# 99   33603.33
# 100  32520.17
# 101  32562.77
# 102  32570.03
# 103  32770.03
# 104  32780.03
# 105  32790.03
# 106  31706.87
# 107  32016.87
# 108  32024.31
# 109  32224.31
# 110  32274.31
# 111  32324.31
# 112  32358.41
# 113  32408.41
# 114  32458.41
# 115  32508.41
# 116  31425.25
# 117  31445.25
# 118  31755.25
# 119  31763.06
#
# [120 rows x 5 columns]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
